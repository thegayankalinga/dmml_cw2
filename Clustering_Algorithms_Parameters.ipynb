# %%
pip install hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 42.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/cython/
# Collecting cython<3,>=0.27 (from hdbscan)
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.2.0)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039180 sha256=827cd3c285fa05d5068b29a970640ead9649e31216c96440c1afa57d81af07ac
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# Successfully built hdbscan
# Installing collected packages: cython, hdbscan
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.4
#     Uninstalling Cython-3.0.4:
#       Successfully uninstalled Cython-3.0.4
# Successfully installed cython-0.29.36 hdbscan-0.8.33

# %%
from sklearn.pipeline import Pipeline
from sklearn.cluster import MeanShift
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering
from hdbscan import HDBSCAN
from sklearn.cluster import Birch
from sklearn.cluster import OPTICS

model = Pipeline(steps=[
    ("MeanShift",MeanShift()),
    ("KMeans", KMeans()),
    ("DBSCAN", DBSCAN()),
    ("AffinityPropagation", AffinityPropagation()),
    ("SpectralClustering", SpectralClustering()),
    ("AgglomerativeClustering", AgglomerativeClustering()),
    ("HDBSCAN", HDBSCAN()),
    ("Birch", Birch()),
    ("OPTICS", OPTICS()),
])

for parameter in model.get_params():
    print(parameter)
# Out:
# memory
# steps
# verbose
# MeanShift
# KMeans
# DBSCAN
# AffinityPropagation
# SpectralClustering
# AgglomerativeClustering
# HDBSCAN
# Birch
# OPTICS
# MeanShift__bandwidth
# MeanShift__bin_seeding
# MeanShift__cluster_all
# MeanShift__max_iter
# MeanShift__min_bin_freq
# MeanShift__n_jobs
# MeanShift__seeds
# KMeans__algorithm
# KMeans__copy_x
# KMeans__init
# KMeans__max_iter
# KMeans__n_clusters
# KMeans__n_init
# KMeans__random_state
# KMeans__tol
# KMeans__verbose
# DBSCAN__algorithm
# DBSCAN__eps
# DBSCAN__leaf_size
# DBSCAN__metric
# DBSCAN__metric_params
# DBSCAN__min_samples
# DBSCAN__n_jobs
# DBSCAN__p
# AffinityPropagation__affinity
# AffinityPropagation__convergence_iter
# AffinityPropagation__copy
# AffinityPropagation__damping
# AffinityPropagation__max_iter
# AffinityPropagation__preference
# AffinityPropagation__random_state
# AffinityPropagation__verbose
# SpectralClustering__affinity
# SpectralClustering__assign_labels
# SpectralClustering__coef0
# SpectralClustering__degree
# SpectralClustering__eigen_solver
# SpectralClustering__eigen_tol
# SpectralClustering__gamma
# SpectralClustering__kernel_params
# SpectralClustering__n_clusters
# SpectralClustering__n_components
# SpectralClustering__n_init
# SpectralClustering__n_jobs
# SpectralClustering__n_neighbors
# SpectralClustering__random_state
# SpectralClustering__verbose
# AgglomerativeClustering__affinity
# AgglomerativeClustering__compute_distances
# AgglomerativeClustering__compute_full_tree
# AgglomerativeClustering__connectivity
# AgglomerativeClustering__distance_threshold
# AgglomerativeClustering__linkage
# AgglomerativeClustering__memory
# AgglomerativeClustering__metric
# AgglomerativeClustering__n_clusters
# HDBSCAN__algorithm
# HDBSCAN__allow_single_cluster
# HDBSCAN__alpha
# HDBSCAN__approx_min_span_tree
# HDBSCAN__cluster_selection_epsilon
# HDBSCAN__cluster_selection_method
# HDBSCAN__core_dist_n_jobs
# HDBSCAN__gen_min_span_tree
# HDBSCAN__leaf_size
# HDBSCAN__match_reference_implementation
# HDBSCAN__max_cluster_size
# HDBSCAN__memory
# HDBSCAN__metric
# HDBSCAN__min_cluster_size
# HDBSCAN__min_samples
# HDBSCAN__p
# HDBSCAN__prediction_data
# Birch__branching_factor
# Birch__compute_labels
# Birch__copy
# Birch__n_clusters
# Birch__threshold
# OPTICS__algorithm
# OPTICS__cluster_method
# OPTICS__eps
# OPTICS__leaf_size
# OPTICS__max_eps
# OPTICS__memory
# OPTICS__metric
# OPTICS__metric_params
# OPTICS__min_cluster_size
# OPTICS__min_samples
# OPTICS__n_jobs
# OPTICS__p
# OPTICS__predecessor_correction
# OPTICS__xi
